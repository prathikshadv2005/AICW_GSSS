# %%
import cv2
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in C:\Users\mrudu\AppData\Roaming\Python\Python314\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in C:\Users\mrudu\AppData\Roaming\Python\Python314\site-packages (from opencv-python) (2.5.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install make
# Out:
# Collecting make
#   Downloading make-0.1.6.post2-py3-none-any.whl.metadata (4.6 kB)
# Collecting Jinja2 (from make)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jinja2-time (from make)
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2->make)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting arrow (from jinja2-time->make)
#   Using cached arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\mrudu\appdata\roaming\python\python312\site-packages (from arrow->jinja2-time->make) (2.9.0.post0)
# Collecting tzdata (from arrow->jinja2-time->make)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mrudu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7.0->arrow->jinja2-time->make) (1.17.0)
# Downloading make-0.1.6.post2-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Using cached arrow-1.4.0-py3-none-any.whl (68 kB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, MarkupSafe, Jinja2, arrow, jinja2-time, make
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.3 arrow-1.4.0 jinja2-time-0.2.0 make-0.1.6.post2 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy>=2 (from opencv-python)
#   Using cached numpy-2.5.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Using cached numpy-2.5.2-cp312-cp312-win_amd64.whl (12.5 MB)
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-2.5.2 opencv-python-5.0.0.93
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
import cv2
import numpy as np

# %% [markdown]
# import cv2
# import numpy as np

# %%
img_path='face.jpg'
img=cv2.imread(img_path)
if img is None:
    print(f'Error: Could not read image from {img_path}')
    exit()
